# %%
import os

os.getcwd()
# !pwd
# os.mkdir("abc") # create a directory
os.makedirs("abc/def") # create a directory with subdirectory, we can make nested sub dirs inside it

# we can join the path using os.path.join
os.path.join("abc", "def", "ghi") # abc/def/ghi
os.makedirs(os.path.join("abc", "def", "ghi")) # create a directory with subdirectory, we can make nested sub dirs inside it

# %%
# to remove folder we need to use rmdir
# os.rmdir("abc/def/ghi") # remove the directory
# os.rmdir("abc/def") # remove the directory

# since now after deleting all those sub folders we can now delete the parent folder
# os.rmdir("abc") # remove the directory



# or we could have deleted all the contents of the folder in one go by this -->
# !rm -r abc # it is a shell/unix command to remove the directory and all its contents

# %%
# list all the directories

os.listdir() # list all the directories
# Out:
# ['01_DataCorpusFromAFile.ipynb', '01_OS_Basics.ipynb']
