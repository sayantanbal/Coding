# %%
fd = open("inventory.txt", 'w')
fd.close()

# %% [markdown]
# ### params
# 1. Product ID
# 2. Name
# 3. Category
# 4. Quantity
# 5. Price

# %%
fd = open("inventory.txt", 'r')
txt = fd.read()

# %%
txt
# Out:
# '1,5-Star,Chocolate,100,10\n2,Cranberries,Dried Fruits,200,200\n3,Almonds,Dried Fruits,300,100\n4,Cashews,Dried Fruits,400,100'

# %%
newList = txt.split('\n')

# %%
len(newList)
# Out:
# 4
