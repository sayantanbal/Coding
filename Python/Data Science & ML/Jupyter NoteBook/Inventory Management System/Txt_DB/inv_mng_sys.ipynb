# %%
fd = open("inventory.txt", 'w')
fd.close()

# %% [markdown]
# ### params
# 1. Product ID
# 2. Name
# 3. Category
# 4. Quantity
# 5. Price

# %%
fd = open("inventory.txt", 'r')
txt = fd.read()

# %%
txt
# Out:
# '1, 5 Star, 10, 100\n2, Dairy Milk, 20, 50\n3, KitKat, 30, 30'

# %%
newList = txt.split('\n')
print(newList)
# Out:
# ['1, 5 Star, 10, 100', '2, Dairy Milk, 20, 50', '3, KitKat, 30, 30']

# %%
len(newList)
# Out:
# 3
